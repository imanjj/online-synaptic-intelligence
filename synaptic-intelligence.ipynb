# %%
import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
sess = tf.InteractiveSession()

g = tf.Graph()

# %%
# Parameters
learning_rate = 1e-3
datasetReviewNum = 50
batch_size = 100
display_step = 50

# synapctic loss regularizer
gamma = 0.1

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.5 # Dropout, probability to keep units

# Moving Average Parameters
alpha = 0.95
alphaOmega = alpha
alphaDelta = alpha
alphaParam = 0.5

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
withSI = True

keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
def calcSynapseWeight(omega, delta, epsilon = 1e-8):
    # input:
    # omega: param length, unscaled importance
    # delta: param length, scaling value
    # epsilon: 1 length, lower bound for determinant
    # output: omega/(delta^2 + epsilon). The power and divisions are elementwise
    return omega/(delta**2 + epsilon)

# %%
def synapseLoss(synapseWeight, theta, thetaStar):
    # input: 
    # synapseWeight: param length
    # theta: param length, current param value
    # thetaStar: param length, moving average value of params
    # output: synapseWeight*(theta - thetaStar)^2 all multiplications are elementwise
    return synapseWeight*((theta - thetaStar)**2)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.truncated_normal([5, 5, 1, 32], stddev=0.1)),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.truncated_normal([5, 5, 32, 64], stddev=0.1)),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.truncated_normal([7*7*64, 1024], stddev=0.1)),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.truncated_normal([1024, n_classes], stddev=0.1))
}

biases = {
    'bc1': tf.Variable(tf.constant(0.1, shape=[32])),
    'bc2': tf.Variable(tf.constant(0.1, shape=[64])),
    'bd1': tf.Variable(tf.constant(0.1, shape=[1024])),
    'out': tf.Variable(tf.constant(0.1, shape=[n_classes]))
}

numParamMats = len(tf.trainable_variables())

synapseWeight = [tf.Variable(tf.zeros(var.shape), trainable = False) for var in tf.trainable_variables()]
numParams = tf.cast(tf.add_n([tf.size(tf.trainable_variables()[i]) for i in range(numParamMats)]), tf.float32)
# Define moving average operations
with tf.name_scope("emaOp"):
    emaOmegaOp = tf.train.ExponentialMovingAverage(alphaOmega, zero_debias = True, name = 'movingAvgOmegaOp')
    emaDeltaOp = tf.train.ExponentialMovingAverage(alphaDelta, zero_debias = True, name = 'movingDeltaAvgOp')
    emaParamOp = tf.train.ExponentialMovingAverage(alphaParam, zero_debias = False, name = 'movingParamAvgOp')

# %%
with tf.name_scope("emaParamUpdate"):
    emaParamOp_assign = emaParamOp.apply(tf.trainable_variables())

# Define NN upto the loss
with tf.name_scope("NN"):
        pred = conv_net(x, weights, biases, keep_prob)

with tf.name_scope("eval"):
    with tf.control_dependencies([pred]):
        correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
        accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

with tf.name_scope("loss"):
    with tf.control_dependencies([emaParamOp_assign]):
        classCost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
        synapseCost = [synapseLoss(synapseWeight[i], tf.trainable_variables()[i], emaParamOp.average(tf.trainable_variables()[i])) for i in range(numParamMats)]
        sc = tf.add_n([tf.reduce_sum(synapseCost[i]) for i in range(numParamMats)])#/numParams
        if (withSI == True):
            cost = classCost + gamma*sc
        else:
            cost = classCost

# Define old variable param
with tf.name_scope("oldParam"):
    oldParams = [tf.trainable_variables()[i]*tf.constant(1.) for i in range(numParamMats)]

# %%
with tf.name_scope("optimize"):
    with tf.control_dependencies(oldParams):
        # Calculate gradients with respect to this loss  
        classGrad = tf.gradients(classCost, tf.trainable_variables(), name = 'MGRADIENT')
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

with tf.name_scope("emaUpdate"):
    with tf.control_dependencies([optimizer]):
        deltaParams = [tf.trainable_variables()[i] - oldParams[i] for i in range(numParamMats)]
        score = [tf.maximum(-classGrad[i]*deltaParams[i], tf.constant(0.)) for i in range(numParamMats)]
        emaOmegaOp_assign = emaOmegaOp.apply(score)
        emaDeltaOp_assign = emaDeltaOp.apply(deltaParams)

with tf.name_scope("assignSynapseWeight"):
    with tf.control_dependencies([emaOmegaOp_assign, emaDeltaOp_assign, emaParamOp_assign]):
        assignSynapseWeightOp = [synapseWeight[i].assign(calcSynapseWeight(emaOmegaOp.average(score[i]), emaDeltaOp.average(deltaParams[i]))) for i in range(numParamMats)]        

with tf.name_scope("init"):
    init = tf.global_variables_initializer()

# %%
    # Define NN upto the loss
    # grad = Calculate gradients with respect to this loss
    # define MA ops:
        # exponentialAverage(omega, grad*(oldParam-flatennedParam), alphaOmega)
        # exponentialAverage(delta, flatennedParam-oldParam, alphaDelta)
        # exponentialAverage(paramStar, flatennedParam, alphaParam)
    # assign MA output to vars.
    
    # flatennedParam = flatten(param) # make sure the ordering is the same as grad output
    # oldParam = flatennedParam
    # synWeight = calcSynapseWeight(omegaMA, deltaMA)
    # minimize (loss + synapseLoss(synWeight, param, thetaMA))
    
    # update MAs with the minimize output's control dependency
    
# TODO: learn how to copy parameters to be used as oldParams

# %%
# Launch the graph
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
training_iters = int(datasetReviewNum* mnist.train.images.shape[0]/batch_size)
writer = tf.summary.FileWriter('./logs/synapticIntelligence', graph=tf.get_default_graph())
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        #sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
        #                               keep_prob: dropout})
        
        #loss, acc, s, nump, sync = sess.run([classCost, accuracy, score, numParams, sc], feed_dict={x: batch_x,
        #                                                      y: batch_y,
        #                                                      keep_prob: dropout})
        loss, classLoss, sLoss, acc, _ = sess.run([cost, classCost, sc, accuracy, assignSynapseWeightOp], 
                                          feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
        #loss, classLoss, acc, _ = sess.run([cost, classCost, accuracy, optimizer], 
        #                                  feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
        
        
        if step % display_step == 0:
            print "sample time " + "{:.2f}".format((step*batch_size/ np.float32(mnist.train.images.shape[0]))) + \
                  ", Minibatch classLoss= " + "{:.6f}".format(classLoss) + \
                  ", sLoss= " + "{:.6f}".format(sLoss) + \
                  ", Loss= " + "{:.6f}".format(loss) + \
                    ", Tr Acc= " + "{:.5f}".format(acc)
                    
        if step % (display_step*5) == 0:
            acc_list = []
            fromIx_list = []
            toIx_list = []
            nTestBatch = int(np.floor(mnist.test.images.shape[0]/batch_size))
            for i in range(nTestBatch):
                fromIx = i*batch_size
                toIx = min((i+1)*batch_size, mnist.test.images.shape[0])         
                curAcc = sess.run(accuracy, feed_dict={x: mnist.test.images[fromIx:toIx],
                                                       y: mnist.test.labels[fromIx:toIx],
                                                       keep_prob: 1.})
                fromIx_list.append(fromIx)
                toIx_list.append(toIx)
                acc_list.append(curAcc)
            print "Testing Accuracy:", np.mean(acc_list)
            
        step += 1
    
    acc_list = []
    fromIx_list = []
    toIx_list = []
    nTestBatch = int(np.floor(mnist.test.images.shape[0]/batch_size))
    for i in range(nTestBatch):
        fromIx = i*batch_size
        toIx = min((i+1)*batch_size, mnist.test.images.shape[0])         
        curAcc = sess.run(accuracy, feed_dict={x: mnist.test.images[fromIx:toIx],
                                               y: mnist.test.labels[fromIx:toIx],
                                               keep_prob: 1.})
        fromIx_list.append(fromIx)
        toIx_list.append(toIx)
        acc_list.append(curAcc)
    print "Testing Accuracy:", np.mean(acc_list)     
    sess.close()
    print "Optimization Finished!"
writer.close()
# Calculate accuracy for 256 mnist test images
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# sample time 0.09, Minibatch classLoss= 0.639127, sLoss= 0.133357, Loss= 0.652463, Tr Acc= 0.79000
# sample time 0.18, Minibatch classLoss= 0.345801, sLoss= 0.077813, Loss= 0.353583, Tr Acc= 0.87000
# sample time 0.27, Minibatch classLoss= 0.435721, sLoss= 0.038561, Loss= 0.439577, Tr Acc= 0.90000
# sample time 0.36, Minibatch classLoss= 0.195080, sLoss= 0.064221, Loss= 0.201502, Tr Acc= 0.95000
# sample time 0.45, Minibatch classLoss= 0.074921, sLoss= 0.080159, Loss= 0.082937, Tr Acc= 0.99000
# Testing Accuracy: 0.966
# sample time 0.55, Minibatch classLoss= 0.052160, sLoss= 0.051112, Loss= 0.057272, Tr Acc= 0.99000
# sample time 0.64, Minibatch classLoss= 0.169466, sLoss= 0.066657, Loss= 0.176132, Tr Acc= 0.97000
# sample time 0.73, Minibatch classLoss= 0.196654, sLoss= 0.065818, Loss= 0.203236, Tr Acc= 0.93000
# sample time 0.82, Minibatch classLoss= 0.165401, sLoss= 0.077662, Loss= 0.173167, Tr Acc= 0.94000
# sample time 0.91, Minibatch classLoss= 0.042666, sLoss= 0.048818, Loss= 0.047548, Tr Acc= 0.99000
# Testing Accuracy: 0.9795
# sample time 1.00, Minibatch classLoss= 0.053991, sLoss= 0.053308, Loss= 0.059322, Tr Acc= 0.99000
# sample time 1.09, Minibatch classLoss= 0.102784, sLoss= 0.074516, Loss= 0.110236, Tr Acc= 0.96000
# sample time 1.18, Minibatch classLoss= 0.083114, sLoss= 0.049523, Loss= 0.088067, Tr Acc= 0.96000
# sample time 1.27, Minibatch classLoss= 0.095568, sLoss= 0.045457, Loss= 0.100114, Tr Acc= 0.99000
# sample time 1.36, Minibatch classLoss= 0.085611, sLoss= 0.027277, Loss= 0.088339, Tr Acc= 0.96000
# Testing Accuracy: 0.9837
# sample time 1.45, Minibatch classLoss= 0.042186, sLoss= 0.049499, Loss= 0.047136, Tr Acc= 0.99000
# sample time 1.55, Minibatch classLoss= 0.007725, sLoss= 0.048724, Loss= 0.012597, Tr Acc= 1.00000
# sample time 1.64, Minibatch classLoss= 0.031807, sLoss= 0.042480, Loss= 0.036055, Tr Acc= 0.99000
# sample time 1.73, Minibatch classLoss= 0.058079, sLoss= 0.055204, Loss= 0.063599, Tr Acc= 0.98000
# sample time 1.82, Minibatch classLoss= 0.025970, sLoss= 0.034994, Loss= 0.029469, Tr Acc= 0.99000
# Testing Accuracy: 0.9836
# sample time 1.91, Minibatch classLoss= 0.126565, sLoss= 0.052941, Loss= 0.131859, Tr Acc= 0.98000
# sample time 2.00, Minibatch classLoss= 0.099171, sLoss= 0.041388, Loss= 0.103309, Tr Acc= 0.97000
# sample time 2.09, Minibatch classLoss= 0.121556, sLoss= 0.020003, Loss= 0.123556, Tr Acc= 0.99000
# sample time 2.18, Minibatch classLoss= 0.039800, sLoss= 0.074312, Loss= 0.047231, Tr Acc= 0.99000
# sample time 2.27, Minibatch classLoss= 0.078398, sLoss= 0.043908, Loss= 0.082789, Tr Acc= 0.97000
# Testing Accuracy: 0.9873
# sample time 2.36, Minibatch classLoss= 0.023389, sLoss= 0.034275, Loss= 0.026816, Tr Acc= 0.99000
# sample time 2.45, Minibatch classLoss= 0.004039, sLoss= 0.033394, Loss= 0.007378, Tr Acc= 1.00000
# sample time 2.55, Minibatch classLoss= 0.109490, sLoss= 0.033429, Loss= 0.112833, Tr Acc= 0.97000
# sample time 2.64, Minibatch classLoss= 0.008552, sLoss= 0.026827, Loss= 0.011235, Tr Acc= 1.00000
# sample time 2.73, Minibatch classLoss= 0.003534, sLoss= 0.031348, Loss= 0.006669, Tr Acc= 1.00000
# Testing Accuracy: 0.9873
# sample time 2.82, Minibatch classLoss= 0.047688, sLoss= 0.023719, Loss= 0.050059, Tr Acc= 0.99000
# sample time 2.91, Minibatch classLoss= 0.062599, sLoss= 0.020203, Loss= 0.064620, Tr Acc= 0.98000
# sample time 3.00, Minibatch classLoss= 0.028506, sLoss= 0.040697, Loss= 0.032575, Tr Acc= 0.99000
# sample time 3.09, Minibatch classLoss= 0.013902, sLoss= 0.068272, Loss= 0.020730, Tr Acc= 1.00000
# sample time 3.18, Minibatch classLoss= 0.018918, sLoss= 0.035487, Loss= 0.022466, Tr Acc= 0.99000
# Testing Accuracy: 0.9874
# sample time 3.27, Minibatch classLoss= 0.023799, sLoss= 0.017803, Loss= 0.025579, Tr Acc= 0.99000
# sample time 3.36, Minibatch classLoss= 0.023176, sLoss= 0.024923, Loss= 0.025668, Tr Acc= 0.99000
# sample time 3.45, Minibatch classLoss= 0.011550, sLoss= 0.044521, Loss= 0.016003, Tr Acc= 1.00000
# sample time 3.55, Minibatch classLoss= 0.015109, sLoss= 0.020518, Loss= 0.017160, Tr Acc= 1.00000
# sample time 3.64, Minibatch classLoss= 0.026329, sLoss= 0.027946, Loss= 0.029123, Tr Acc= 0.98000
# Testing Accuracy: 0.9889
# sample time 3.73, Minibatch classLoss= 0.032353, sLoss= 0.029702, Loss= 0.035324, Tr Acc= 0.99000
# sample time 3.82, Minibatch classLoss= 0.062897, sLoss= 0.033973, Loss= 0.066294, Tr Acc= 0.99000
# sample time 3.91, Minibatch classLoss= 0.042133, sLoss= 0.042278, Loss= 0.046360, Tr Acc= 0.99000
# sample time 4.00, Minibatch classLoss= 0.057356, sLoss= 0.065737, Loss= 0.063930, Tr Acc= 0.98000
# sample time 4.09, Minibatch classLoss= 0.006380, sLoss= 0.022496, Loss= 0.008629, Tr Acc= 1.00000
# Testing Accuracy: 0.9903
# sample time 4.18, Minibatch classLoss= 0.034987, sLoss= 0.040481, Loss= 0.039035, Tr Acc= 0.98000
# sample time 4.27, Minibatch classLoss= 0.051145, sLoss= 0.056920, Loss= 0.056837, Tr Acc= 0.99000
# sample time 4.36, Minibatch classLoss= 0.011076, sLoss= 0.022074, Loss= 0.013284, Tr Acc= 1.00000
# sample time 4.45, Minibatch classLoss= 0.019514, sLoss= 0.022598, Loss= 0.021774, Tr Acc= 1.00000
# sample time 4.55, Minibatch classLoss= 0.019699, sLoss= 0.020768, Loss= 0.021776, Tr Acc= 1.00000
# Testing Accuracy: 0.9919
# sample time 4.64, Minibatch classLoss= 0.025500, sLoss= 0.023285, Loss= 0.027829, Tr Acc= 1.00000
# sample time 4.73, Minibatch classLoss= 0.008774, sLoss= 0.054017, Loss= 0.014176, Tr Acc= 1.00000
# sample time 4.82, Minibatch classLoss= 0.025993, sLoss= 0.013598, Loss= 0.027353, Tr Acc= 0.98000
# sample time 4.91, Minibatch classLoss= 0.004453, sLoss= 0.024632, Loss= 0.006916, Tr Acc= 1.00000
# sample time 5.00, Minibatch classLoss= 0.006579, sLoss= 0.033182, Loss= 0.009897, Tr Acc= 1.00000
# Testing Accuracy: 0.9919
# sample time 5.09, Minibatch classLoss= 0.021058, sLoss= 0.022556, Loss= 0.023313, Tr Acc= 0.99000
# sample time 5.18, Minibatch classLoss= 0.025474, sLoss= 0.012256, Loss= 0.026700, Tr Acc= 0.99000
# sample time 5.27, Minibatch classLoss= 0.126390, sLoss= 0.066546, Loss= 0.133044, Tr Acc= 0.96000
# sample time 5.36, Minibatch classLoss= 0.020124, sLoss= 0.019922, Loss= 0.022117, Tr Acc= 1.00000
# sample time 5.45, Minibatch classLoss= 0.011819, sLoss= 0.022145, Loss= 0.014034, Tr Acc= 1.00000
# Testing Accuracy: 0.9922
# sample time 5.55, Minibatch classLoss= 0.029055, sLoss= 0.021523, Loss= 0.031208, Tr Acc= 0.99000
# sample time 5.64, Minibatch classLoss= 0.011940, sLoss= 0.050135, Loss= 0.016953, Tr Acc= 0.99000
# sample time 5.73, Minibatch classLoss= 0.048909, sLoss= 0.026713, Loss= 0.051580, Tr Acc= 0.99000
# sample time 5.82, Minibatch classLoss= 0.098394, sLoss= 0.058473, Loss= 0.104241, Tr Acc= 0.98000
# sample time 5.91, Minibatch classLoss= 0.022813, sLoss= 0.043533, Loss= 0.027166, Tr Acc= 0.99000
# Testing Accuracy: 0.9918
# sample time 6.00, Minibatch classLoss= 0.035092, sLoss= 0.012795, Loss= 0.036372, Tr Acc= 0.97000
# sample time 6.09, Minibatch classLoss= 0.004632, sLoss= 0.019627, Loss= 0.006595, Tr Acc= 1.00000
# sample time 6.18, Minibatch classLoss= 0.008231, sLoss= 0.043699, Loss= 0.012601, Tr Acc= 1.00000
# sample time 6.27, Minibatch classLoss= 0.003252, sLoss= 0.049203, Loss= 0.008172, Tr Acc= 1.00000
# sample time 6.36, Minibatch classLoss= 0.011289, sLoss= 0.056292, Loss= 0.016918, Tr Acc= 0.99000
# Testing Accuracy: 0.9926
# sample time 6.45, Minibatch classLoss= 0.009281, sLoss= 0.022517, Loss= 0.011533, Tr Acc= 1.00000
# sample time 6.55, Minibatch classLoss= 0.018530, sLoss= 0.021611, Loss= 0.020691, Tr Acc= 0.99000
# sample time 6.64, Minibatch classLoss= 0.012257, sLoss= 0.015666, Loss= 0.013824, Tr Acc= 0.99000
# sample time 6.73, Minibatch classLoss= 0.008587, sLoss= 0.047689, Loss= 0.013356, Tr Acc= 0.99000
# sample time 6.82, Minibatch classLoss= 0.004988, sLoss= 0.027821, Loss= 0.007770, Tr Acc= 1.00000
# Testing Accuracy: 0.9918
# sample time 6.91, Minibatch classLoss= 0.002014, sLoss= 0.075403, Loss= 0.009555, Tr Acc= 1.00000
# sample time 7.00, Minibatch classLoss= 0.001662, sLoss= 0.038436, Loss= 0.005505, Tr Acc= 1.00000
# sample time 7.09, Minibatch classLoss= 0.003398, sLoss= 0.004568, Loss= 0.003855, Tr Acc= 1.00000
# sample time 7.18, Minibatch classLoss= 0.043086, sLoss= 0.011844, Loss= 0.044271, Tr Acc= 0.98000
# sample time 7.27, Minibatch classLoss= 0.032998, sLoss= 0.010715, Loss= 0.034069, Tr Acc= 0.98000
# Testing Accuracy: 0.9922
# sample time 7.36, Minibatch classLoss= 0.024368, sLoss= 0.057123, Loss= 0.030081, Tr Acc= 0.98000
# sample time 7.45, Minibatch classLoss= 0.012227, sLoss= 0.080488, Loss= 0.020276, Tr Acc= 0.99000
# sample time 7.55, Minibatch classLoss= 0.002214, sLoss= 0.077079, Loss= 0.009922, Tr Acc= 1.00000
# sample time 7.64, Minibatch classLoss= 0.011789, sLoss= 0.070022, Loss= 0.018791, Tr Acc= 0.99000
# sample time 7.73, Minibatch classLoss= 0.005326, sLoss= 0.009936, Loss= 0.006319, Tr Acc= 1.00000
# Testing Accuracy: 0.9901
# sample time 7.82, Minibatch classLoss= 0.002301, sLoss= 0.051193, Loss= 0.007420, Tr Acc= 1.00000
# sample time 7.91, Minibatch classLoss= 0.049376, sLoss= 0.023268, Loss= 0.051703, Tr Acc= 0.99000
# sample time 8.00, Minibatch classLoss= 0.009110, sLoss= 0.054472, Loss= 0.014557, Tr Acc= 1.00000
# sample time 8.09, Minibatch classLoss= 0.004311, sLoss= 0.058646, Loss= 0.010175, Tr Acc= 1.00000
# sample time 8.18, Minibatch classLoss= 0.008433, sLoss= 0.043220, Loss= 0.012755, Tr Acc= 1.00000
# Testing Accuracy: 0.9916
# sample time 8.27, Minibatch classLoss= 0.003323, sLoss= 0.136229, Loss= 0.016946, Tr Acc= 1.00000
# sample time 8.36, Minibatch classLoss= 0.002711, sLoss= 0.016605, Loss= 0.004371, Tr Acc= 1.00000
# sample time 8.45, Minibatch classLoss= 0.003061, sLoss= 0.074433, Loss= 0.010504, Tr Acc= 1.00000
# sample time 8.55, Minibatch classLoss= 0.001453, sLoss= 0.052209, Loss= 0.006674, Tr Acc= 1.00000
# sample time 8.64, Minibatch classLoss= 0.001371, sLoss= 0.075821, Loss= 0.008953, Tr Acc= 1.00000
# Testing Accuracy: 0.9934
# sample time 8.73, Minibatch classLoss= 0.010771, sLoss= 0.034378, Loss= 0.014208, Tr Acc= 1.00000
# sample time 8.82, Minibatch classLoss= 0.006715, sLoss= 0.032436, Loss= 0.009958, Tr Acc= 1.00000
# sample time 8.91, Minibatch classLoss= 0.010519, sLoss= 0.080463, Loss= 0.018565, Tr Acc= 0.99000
# sample time 9.00, Minibatch classLoss= 0.002340, sLoss= 0.074066, Loss= 0.009746, Tr Acc= 1.00000
# sample time 9.09, Minibatch classLoss= 0.021765, sLoss= 0.073677, Loss= 0.029132, Tr Acc= 0.99000
# Testing Accuracy: 0.9916
# sample time 9.18, Minibatch classLoss= 0.000169, sLoss= 0.046042, Loss= 0.004774, Tr Acc= 1.00000
# sample time 9.27, Minibatch classLoss= 0.002171, sLoss= 0.014343, Loss= 0.003605, Tr Acc= 1.00000
# sample time 9.36, Minibatch classLoss= 0.008746, sLoss= 0.054109, Loss= 0.014157, Tr Acc= 1.00000
# sample time 9.45, Minibatch classLoss= 0.000507, sLoss= 0.016908, Loss= 0.002198, Tr Acc= 1.00000
# sample time 9.55, Minibatch classLoss= 0.060152, sLoss= 0.037924, Loss= 0.063944, Tr Acc= 0.98000
# Testing Accuracy: 0.9929
# sample time 9.64, Minibatch classLoss= 0.004017, sLoss= 0.024623, Loss= 0.006479, Tr Acc= 1.00000
# sample time 9.73, Minibatch classLoss= 0.053920, sLoss= 0.011708, Loss= 0.055091, Tr Acc= 0.99000
# sample time 9.82, Minibatch classLoss= 0.001004, sLoss= 0.027333, Loss= 0.003737, Tr Acc= 1.00000
# sample time 9.91, Minibatch classLoss= 0.008684, sLoss= 0.020536, Loss= 0.010738, Tr Acc= 0.99000
# sample time 10.00, Minibatch classLoss= 0.026549, sLoss= 0.123862, Loss= 0.038935, Tr Acc= 0.98000
# Testing Accuracy: 0.9902

# %%
np.floor(np.ndarray(shape=(3)))[0:1]
